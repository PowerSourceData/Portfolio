-- %%
-- Presentation Schema (P): Snapshot View
-- Pass-through view from t-Schema for reporting layer
CREATE OR REPLACE VIEW thekitchen.p.MoatScoring_SnapshotView AS
SELECT
  *
FROM
  thekitchen.t.MoatScoring_SnapshotView;
