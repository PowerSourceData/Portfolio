-- %%
-- Snapshot Fact Table erstellen (ohne SCD Type 2 Overhead)
CREATE OR REPLACE TABLE thekitchen.t.MoatScoring_Snapshot (
  snapshot_date DATE NOT NULL,
  company STRING NOT NULL,
  system_role STRING,
  system_role_id INT,
  s1_substitution_test DOUBLE,
  s2_source_of_enforcement BIGINT,
  s3_replacement_time DOUBLE,
  s4_capital_knowhow DOUBLE,
  s5_demand_enforcement DOUBLE,
  s6_moat_decay_test DOUBLE,
  moat_vector_trend STRING,
  aggregated_score DOUBLE,
  decay_adjusted_score DOUBLE,
  classification STRING,
  strategic_takeaway STRING,
  CONSTRAINT pk_moat_snapshot PRIMARY KEY (snapshot_date, company)
) USING DELTA;
