-- %%
-- View mit PascalCase für SystemRole Referenztabelle
CREATE OR REPLACE VIEW thekitchen.t.MoatScoring_SystemRole AS
SELECT
  RoleID AS RoleId,
  Rank,
  Rolle AS Role,
  Definition_Kriterien AS DefinitionCriteria,
  Beispiele AS Examples
FROM thekitchen.s.SystemRole;
