-- %%
-- View mit PascalCase für Kompatibilität
CREATE OR REPLACE VIEW thekitchen.t.MoatScoring_SnapshotView AS
SELECT
  snapshot_date AS SnapshotDate,
  company AS Company,
  system_role AS SystemRole,
  system_role_id AS SystemRoleId,
  s1_substitution_test AS S1SubstitutionTest,
  s2_source_of_enforcement AS S2SourceOfEnforcement,
  s3_replacement_time AS S3ReplacementTime,
  s4_capital_knowhow AS S4CapitalKnowHow,
  s5_demand_enforcement AS S5DemandEnforcement,
  s6_moat_decay_test AS S6MoatDecayTest,
  moat_vector_trend AS MoatVectorTrend,
  aggregated_score AS AggregatedScore,
  decay_adjusted_score AS DecayAdjustedScore,
  classification AS Classification,
  strategic_takeaway AS StrategicTakeaway
FROM thekitchen.t.MoatScoring_Snapshot;
