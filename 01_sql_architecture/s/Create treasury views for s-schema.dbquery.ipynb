-- %%
-- Create View from av.two_year_treasury
CREATE OR REPLACE VIEW s.two_year_treasury AS
SELECT
  *
FROM
  two_year_treasury;

-- Create View from av.five_year_treasury
CREATE OR REPLACE VIEW s.five_year_treasury AS
SELECT
  *
FROM
  five_year_treasury;

-- Create View from av.ten_year_treasury
CREATE OR REPLACE VIEW s.ten_year_treasury AS
SELECT
  *
FROM
  ten_year_treasury
