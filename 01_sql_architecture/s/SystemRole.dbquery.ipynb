-- %%
-- Tabelle SystemRole erstellen
CREATE OR REPLACE TABLE thekitchen.s.SystemRole (
  RoleID INT,
  Rank STRING,
  Rolle STRING,
  Definition_Kriterien STRING,
  Beispiele STRING
);

-- Daten einfügen
INSERT INTO thekitchen.s.SystemRole VALUES
  (1, 'SR-1', 'Global Choke Point', 'Strukturelle Nadelöhre. Ohne dieses Unternehmen bricht die globale Wertschöpfungskette oder der Kapitalfluss sofort zusammen. Regulatorisch oder technologisch unumgänglich.', 'ASML, S&P Global, Visa, LSEG, Safran.'),
  (2, 'SR-2', 'System Backbone', 'Digitale/Physische Basis. Die Infrastruktur, auf der andere Unternehmen aufbauen. Hohe Wechselkosten, aber theoretisch (langfristig) ersetzbar.', 'Microsoft, AWS, SAP, BASF (Verbund).'),
  (3, 'SR-3', 'Standard Setter', 'Regulatorische Gatekeeper. Definieren Regeln, Protokolle oder Normen. Besitzen die "Sprache" einer Branche, aber nicht zwingend die Abwicklungs-Infrastruktur.', 'Moody\'s, GS1, ISO-Zertifizierer.'),
  (4, 'SR-4', 'Critical Infrastructure', 'Physische Lebensadern. Lokale oder regionale Monopole für Energie, Transport und Logistik. Oft staatlich reguliert mit Renditedeckelung.', 'Enbridge, Union Pacific, National Grid.'),
  (5, 'SR-5', 'Essential Component', 'Kritische Zulieferer. Ein Ausfall führt zu Produktionsstopps, aber das Unternehmen kontrolliert nicht das gesamte System.', 'Linde, TSMC (Fertigung), Givaudan.'),
  (6, 'SR-6', 'Specialized Service', 'Experten-Lock-in. Hochgradig spezialisierte Dienstleister mit tiefem Prozesswissen beim Kunden.', 'Accenture, Dassault Systèmes, ServiceNow.'),
  (7, 'SR-7', 'Scale Giant', 'Skaleneffekte. Wettbewerbsvorteil rein durch Größe und Kostenführerschaft. Substituierbar, wenn Konkurrenten massiv investieren.', 'Amazon (Retail), Walmart, Maersk.'),
  (8, 'SR-8', 'Brand Power', 'Psychologischer Moat. Hohe Kundenbindung durch Emotion und Marke. Funktional oft leicht ersetzbar.', 'Apple, LVMH, Coca-Cola.'),
  (9, 'SR-9', 'Commodity Player', 'Preiskampf. Austauschbare Güter ohne nennenswerte Differenzierung.', 'Bergbau (Standard-Erze), Agrarrohstoffe.'),
  (10, 'SR-10', 'Optional Service', 'Lifestyle & Luxus. Rein optionaler Konsum. Bei Krisen verzichten Kunden als Erstes hierauf.', 'Netflix, Starbucks, Peloton.');

-- Tabelle anzeigen
SELECT * FROM thekitchen.s.SystemRole ORDER BY RoleID;
